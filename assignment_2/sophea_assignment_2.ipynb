# %% [markdown]
# # Graded Exercise 2: Anomaly Detection on Acoustic Data

# %% [markdown]
# - **Course**: [CIVIL-426 - Machine Learning for Predictive Maintenance](https://edu.epfl.ch/coursebook/en/machine-learning-for-predictive-maintenance-applications-CIVIL-426)
# - **Start Date**: 2024.10.03 at 10:15
# - **Due Date**: 2024.10.23 at 23:59
# - **Student 0**:
#     - Name: `FILL HERE`
#     - SCIPER: `FILL HERE`
# - **Student 1**:
#     - Name: `FILL HERE`
#     - SCIPER: `FILL HERE`

# %% [markdown]
# # Introduction
# Anomalous sound detection (ASD) refers to the task of identifying whether the sounds emitted from a target machine are normal or anomalous.
# In real-world industrial environments, anomalies are infrequent and can exhibit significant variability, making it impractical to build an exhaustive set of anomalous sound patterns.
# As a result, our goal is to detect anomalous sounds using only normal sound clips for training.
#
# This challenge cannot be approached as a simple classification problem (anomaly vs healthy). Instead, it is formulated as a **one-class classification** problem, where the model is trained on normal sound data to detect deviations from the learned pattern.
#
# Anomalous sound detection can be achieved with following steps:
#    - Feature Extraction (I)
#    - One-class Classifier Training (II)
#    - Decisions based on a threshold from your trained classifier (III)
#
# Through this assignment, you will primarily focus on tasks (I) and (II).
# The quality of your one-class classifier will be assessed using the **Area Under the Curve (AUC)** score on the test dataset.
#
# The model used here is a type of neural network called **AutoEncoder** (AE). AE is trained to reconstruct the input data while compressing the input data into a lower-dimensional latent space and minimizing information loss during this process.
# Thus, you will also modify the extracted features and Neural Network used in this notebook to improve the anomalous sound detection performance.
#
# The dataset is composed of two different machines, a Pump and a Valve. For each machine you have:
# - A **training dataset** composed of *only healthy* sound data
# - A **test dataset** composed of *both healthy and abnormal* sound data

# %% [markdown]
# # Questions:
#
# Your task is to improve the anomalous sound detection performance by modifying the feature extraction process and neural network architecture. You are expected to experiment with various feature representations and neural network configurations to optimize detection results.
#
# Specifically, the following questions must be addressed. Each question should be discussed separately for both the Pump and Valve datasets. The answers are to be provided in a PDF report, and the full Jupyter notebook must also be submitted.
#
# **Question 1:** Given the provided code, fill in the blank spaces to extract signal features, train a simple AutoEncoder that reconstructs the inputs MEL-Spectogram, and report the AUC score.
#
# **Question 2:** From the trained AutoEncoder, use the bottleneck features to train both (1) a One-Class SVM and (2) an Isolation Forest, and report the corresponding AUC scores.
#
# **Question 3:** Instead of using AutoEncoder features, apply PCA to project the MEL-spectrogram into a smaller dimensional space, then train (1) a One-Class SVM and (2) an Isolation Forest, and report the AUC scores.
#
# **Question 4:** Determine an appropriate threshold for distinguishing anomalies based on the given results, and compute the following metrics: Accuracy, True Positive Rate (TPR), False Positive Rate (FPR), and F1-score.
#
# **Question 5:** Visualize essential steps and provide a thorough discussion of the results obtained from all the methods.
#
# **Bonus Question:** Modify the AutoEncoder architecture to a 2D AutoEncoder using convolutional layers instead of fully connected layers, and analyze its performance.

# %% [markdown]
# ## Download Dataset

# %%
# %pip install gdown --upgrade --quiet
import gdown
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pump Dataset
gdown.download(id='1ZAqnNW2gnHDyFHGHk3Aru7k-ng-BTpGn', output="./dev_data_pump_04.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZAqnNW2gnHDyFHGHk3Aru7k-ng-BTpGn
# From (redirected): https://drive.google.com/uc?id=1ZAqnNW2gnHDyFHGHk3Aru7k-ng-BTpGn&confirm=t&uuid=c36c7923-019f-4a72-a3bc-978e53486214
# To: /Users/sopheabonnne/EPFL/CIVIL-426/ml4pm/assignment_2/dev_data_pump_04.zip
# 100%|██████████| 199M/199M [00:17<00:00, 11.4MB/s]
# './dev_data_pump_04.zip'

# %%
# Valve Dataset
gdown.download(id='1H_SS7qteLcd44e5CD9CFJjhJ573FAb6M', output="./dev_data_valve_00.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1H_SS7qteLcd44e5CD9CFJjhJ573FAb6M
# From (redirected): https://drive.google.com/uc?id=1H_SS7qteLcd44e5CD9CFJjhJ573FAb6M&confirm=t&uuid=77493bd4-d49c-4dd3-8ce2-10c7cf611d74
# To: /Users/sopheabonnne/EPFL/CIVIL-426/ml4pm/assignment_2/dev_data_valve_00.zip
# 100%|██████████| 269M/269M [00:17<00:00, 15.4MB/s]
# './dev_data_valve_00.zip'

# %% [markdown]
# In case that above links do not work, you can also manully download the dataset here:
# - **dev_data_pump_04.zip**: https://docs.google.com/uc?export=download&id=1ZAqnNW2gnHDyFHGHk3Aru7k-ng-BTpGn
# - **dev_data_valve_00,zip**: https://docs.google.com/uc?export=download&id=1H_SS7qteLcd44e5CD9CFJjhJ573FAb6M

# %%
# !unzip dev_data_pump_04.zip
# !unzip dev_data_valve_00.zip
# Out:
# Archive:  dev_data_pump_04.zip
#    creating: dev_data_pump_04/
#    creating: dev_data_pump_04/pump/
#    creating: dev_data_pump_04/pump/test/
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000000.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000001.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000002.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000003.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000004.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000005.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000006.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000007.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000008.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000009.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000010.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000011.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000012.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000013.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000014.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000015.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000016.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000017.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000018.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000019.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000020.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000021.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000022.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000023.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000024.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000025.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000026.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000027.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000028.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000029.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000030.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000031.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000032.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000033.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000034.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000035.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000036.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000037.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000038.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000039.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000040.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000041.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000042.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000043.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000044.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000045.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000046.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000047.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000048.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000049.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000050.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000051.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000052.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000053.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000054.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000055.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000056.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000057.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000058.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000059.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000060.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000061.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000062.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000063.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000064.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000065.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000066.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000067.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000068.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000069.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000070.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000071.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000072.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000073.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000074.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000075.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000076.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000077.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000078.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000079.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000080.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000081.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000082.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000083.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000084.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000085.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000086.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000087.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000088.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000089.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000090.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000091.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000092.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000093.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000094.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000095.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000096.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000097.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000098.wav
#   inflating: dev_data_pump_04/pump/test/anomaly_id_04_00000099.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000000.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000001.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000002.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000003.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000004.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000005.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000006.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000007.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000008.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000009.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000010.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000011.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000012.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000013.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000014.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000015.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000016.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000017.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000018.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000019.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000020.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000021.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000022.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000023.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000024.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000025.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000026.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000027.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000028.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000029.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000030.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000031.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000032.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000033.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000034.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000035.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000036.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000037.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000038.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000039.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000040.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000041.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000042.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000043.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000044.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000045.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000046.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000047.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000048.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000049.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000050.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000051.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000052.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000053.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000054.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000055.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000056.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000057.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000058.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000059.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000060.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000061.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000062.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000063.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000064.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000065.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000066.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000067.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000068.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000069.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000070.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000071.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000072.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000073.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000074.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000075.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000076.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000077.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000078.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000079.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000080.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000081.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000082.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000083.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000084.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000085.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000086.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000087.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000088.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000089.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000090.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000091.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000092.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000093.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000094.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000095.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000096.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000097.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000098.wav
#   inflating: dev_data_pump_04/pump/test/normal_id_04_00000099.wav
#    creating: dev_data_pump_04/pump/train/
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000000.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000001.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000002.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000003.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000004.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000005.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000006.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000007.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000008.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000009.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000010.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000011.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000012.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000013.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000014.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000015.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000016.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000017.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000018.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000019.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000020.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000021.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000022.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000023.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000024.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000025.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000026.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000027.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000028.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000029.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000030.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000031.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000032.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000033.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000034.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000035.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000036.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000037.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000038.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000039.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000040.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000041.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000042.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000043.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000044.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000045.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000046.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000047.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000048.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000049.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000050.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000051.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000052.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000053.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000054.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000055.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000056.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000057.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000058.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000059.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000060.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000061.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000062.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000063.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000064.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000065.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000066.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000067.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000068.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000069.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000070.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000071.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000072.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000073.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000074.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000075.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000076.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000077.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000078.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000079.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000080.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000081.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000082.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000083.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000084.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000085.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000086.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000087.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000088.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000089.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000090.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000091.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000092.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000093.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000094.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000095.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000096.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000097.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000098.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000099.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000100.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000101.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000102.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000103.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000104.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000105.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000106.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000107.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000108.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000109.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000110.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000111.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000112.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000113.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000114.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000115.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000116.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000117.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000118.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000119.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000120.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000121.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000122.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000123.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000124.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000125.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000126.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000127.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000128.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000129.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000130.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000131.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000132.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000133.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000134.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000135.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000136.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000137.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000138.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000139.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000140.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000141.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000142.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000143.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000144.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000145.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000146.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000147.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000148.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000149.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000150.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000151.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000152.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000153.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000154.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000155.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000156.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000157.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000158.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000159.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000160.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000161.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000162.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000163.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000164.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000165.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000166.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000167.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000168.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000169.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000170.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000171.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000172.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000173.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000174.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000175.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000176.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000177.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000178.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000179.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000180.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000181.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000182.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000183.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000184.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000185.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000186.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000187.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000188.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000189.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000190.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000191.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000192.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000193.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000194.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000195.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000196.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000197.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000198.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000199.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000200.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000201.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000202.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000203.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000204.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000205.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000206.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000207.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000208.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000209.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000210.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000211.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000212.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000213.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000214.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000215.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000216.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000217.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000218.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000219.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000220.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000221.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000222.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000223.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000224.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000225.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000226.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000227.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000228.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000229.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000230.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000231.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000232.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000233.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000234.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000235.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000236.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000237.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000238.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000239.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000240.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000241.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000242.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000243.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000244.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000245.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000246.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000247.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000248.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000249.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000250.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000251.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000252.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000253.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000254.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000255.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000256.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000257.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000258.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000259.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000260.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000261.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000262.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000263.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000264.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000265.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000266.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000267.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000268.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000269.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000270.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000271.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000272.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000273.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000274.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000275.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000276.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000277.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000278.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000279.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000280.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000281.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000282.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000283.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000284.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000285.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000286.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000287.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000288.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000289.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000290.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000291.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000292.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000293.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000294.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000295.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000296.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000297.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000298.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000299.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000300.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000301.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000302.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000303.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000304.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000305.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000306.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000307.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000308.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000309.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000310.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000311.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000312.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000313.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000314.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000315.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000316.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000317.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000318.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000319.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000320.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000321.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000322.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000323.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000324.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000325.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000326.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000327.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000328.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000329.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000330.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000331.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000332.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000333.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000334.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000335.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000336.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000337.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000338.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000339.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000340.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000341.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000342.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000343.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000344.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000345.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000346.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000347.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000348.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000349.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000350.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000351.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000352.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000353.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000354.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000355.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000356.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000357.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000358.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000359.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000360.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000361.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000362.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000363.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000364.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000365.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000366.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000367.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000368.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000369.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000370.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000371.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000372.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000373.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000374.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000375.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000376.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000377.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000378.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000379.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000380.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000381.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000382.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000383.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000384.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000385.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000386.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000387.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000388.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000389.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000390.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000391.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000392.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000393.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000394.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000395.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000396.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000397.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000398.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000399.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000400.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000401.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000402.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000403.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000404.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000405.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000406.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000407.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000408.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000409.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000410.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000411.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000412.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000413.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000414.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000415.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000416.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000417.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000418.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000419.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000420.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000421.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000422.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000423.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000424.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000425.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000426.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000427.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000428.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000429.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000430.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000431.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000432.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000433.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000434.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000435.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000436.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000437.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000438.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000439.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000440.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000441.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000442.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000443.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000444.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000445.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000446.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000447.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000448.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000449.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000450.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000451.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000452.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000453.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000454.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000455.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000456.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000457.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000458.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000459.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000460.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000461.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000462.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000463.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000464.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000465.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000466.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000467.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000468.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000469.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000470.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000471.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000472.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000473.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000474.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000475.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000476.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000477.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000478.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000479.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000480.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000481.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000482.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000483.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000484.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000485.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000486.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000487.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000488.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000489.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000490.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000491.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000492.wav
#   inflating: dev_data_pump_04/pump/train/normal_id_04_00000493.wav
# ...
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000666.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000667.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000668.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000669.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000670.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000671.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000672.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000673.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000674.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000675.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000676.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000677.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000678.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000679.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000680.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000681.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000682.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000683.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000684.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000685.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000686.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000687.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000688.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000689.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000690.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000691.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000692.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000693.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000694.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000695.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000696.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000697.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000698.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000699.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000700.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000701.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000702.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000703.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000704.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000705.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000706.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000707.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000708.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000709.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000710.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000711.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000712.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000713.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000714.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000715.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000716.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000717.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000718.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000719.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000720.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000721.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000722.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000723.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000724.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000725.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000726.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000727.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000728.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000729.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000730.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000731.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000732.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000733.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000734.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000735.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000736.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000737.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000738.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000739.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000740.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000741.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000742.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000743.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000744.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000745.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000746.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000747.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000748.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000749.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000750.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000751.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000752.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000753.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000754.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000755.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000756.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000757.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000758.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000759.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000760.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000761.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000762.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000763.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000764.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000765.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000766.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000767.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000768.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000769.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000770.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000771.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000772.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000773.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000774.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000775.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000776.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000777.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000778.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000779.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000780.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000781.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000782.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000783.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000784.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000785.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000786.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000787.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000788.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000789.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000790.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000791.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000792.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000793.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000794.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000795.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000796.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000797.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000798.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000799.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000800.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000801.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000802.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000803.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000804.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000805.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000806.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000807.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000808.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000809.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000810.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000811.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000812.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000813.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000814.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000815.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000816.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000817.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000818.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000819.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000820.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000821.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000822.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000823.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000824.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000825.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000826.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000827.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000828.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000829.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000830.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000831.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000832.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000833.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000834.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000835.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000836.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000837.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000838.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000839.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000840.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000841.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000842.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000843.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000844.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000845.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000846.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000847.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000848.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000849.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000850.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000851.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000852.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000853.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000854.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000855.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000856.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000857.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000858.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000859.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000860.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000861.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000862.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000863.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000864.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000865.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000866.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000867.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000868.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000869.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000870.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000871.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000872.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000873.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000874.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000875.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000876.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000877.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000878.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000879.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000880.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000881.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000882.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000883.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000884.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000885.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000886.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000887.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000888.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000889.wav
#   inflating: dev_data_valve_00/valve/train/normal_id_00_00000890.wav

# %% [markdown]
# ## Import Dependency

# %%
import os
import sys
import librosa
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from tqdm import tqdm

# %% [markdown]
# ## Audio Data Loading and MEL-Spectrogram Feature Extraction

# %% [markdown]
# The code is adapted from https://github.com/MIMII-hitachi/mimii_baseline
#
# Copyright (C) 2019 Hitachi, Ltd. All right reserved.
#
# Harsh Purohit, Ryo Tanabe, Kenji Ichige, Takashi Endo, Yuki Nikaido, Kaori Suefusa, and Yohei Kawaguchi, "MIMII Dataset: Sound Dataset for Malfunctioning Industrial Machine Investigation and Inspection," arXiv preprint arXiv:1909.09347, 2019.

# %%
########################################################################
# import additional python-library
########################################################################
import librosa.core
import librosa.feature

# WAV File Input
def load_wav_files(wav_file_name, mono=True):
    """Load a .wav file."""
    try:
        return librosa.load(wav_file_name, sr=None, mono=mono)
    except Exception as e:
        print(f"Failed to load file '{wav_file_name}'. Error: {e}")
        raise

def demux_wav_files(wav_file_name, channel=0):
    """Demux a .wav file and return a specific channel."""
    try:
        multi_channel_data, sr = load_wav_files(wav_file_name, mono=False)
        if multi_channel_data.ndim == 1:
            return sr, multi_channel_data
        return sr, multi_channel_data[channel, :]
    except ValueError as e:
        print(f"Error in demuxing file '{wav_file_name}': {e}")
        raise

# Feel free to modify and analysis the images in your report
def plot_signals(tmin, tmax, sr, y, emphasized_y, log_mel_spectrogram):
    plt.figure(1)
    n = len(y)
    t = np.linspace(tmin, tmax, n)
    plt.plot(t, y)
    plt.xlim(t[0],t[-1])
    plt.xlabel('time/s',fontsize=20)
    plt.ylabel('Amplitude',fontsize=20)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid()
    
    plt.figure(2)
    freq = sr/n*np.linspace(0,n/2,int(n/2)+1)
    plt.plot(freq,np.absolute(np.fft.rfft(y[tmin*sr:tmax*sr],n)**2)/n)
    plt.xlim(0,5000)
    plt.xlabel('Frequency/Hz',fontsize=14)
    
    plt.figure(3)
    plt.plot(freq,np.absolute(np.fft.rfft(emphasized_y,n)**2)/n)
    plt.xlim(0,5000)
    plt.xlabel('Frequency/Hz',fontsize=14)
    
    plt.figure(4)
    librosa.display.specshow(log_mel_spectrogram)
    plt.colorbar()

########################################################################
# Feature Extractor
########################################################################
def file_to_features(file_name,
                     n_mels=64,
                     frames=5,
                     n_fft=1024,
                     hop_length=512,
                     power=2.0,
                     plot=True):
    """Convert a WAV file to a vector array."""
    # Step 01: Load the demuxed wav files
    sr, y = demux_wav_files(file_name, channel=0)
    
    # Step 02: Signal Pre-emphasis
    tmin = int(0)
    tmax = int(len(y)/sr)
    alpha = 0.95
    emphasized_y = np.append(y[0],
                             y[1:] - alpha*y[:-1])
    
    # Step 03: Generate MEL-Spectrogram
    # ===================================
    mel_spec = librosa.feature.melspectrogram(y=y, 
                                              sr=sr, 
                                              n_fft=n_fft, 
                                              hop_length=hop_length, 
                                              n_mels = n_mels, 
                                              power = power)
    # ===================================

    # Step 04: Convert MEL-Spectrogram to log scale
    # ===================================
    log_mel_spectrogram = librosa.power_to_db(mel_spec, ref=np.max)
    # ===================================
    
    
    # Step 05: Define Feature Vector Array
    dims = n_mels * frames
    length = len(log_mel_spectrogram[0,:]) - frames + 1
    features = np.zeros((length, dims), float)
    
    # Pad short clips instead of skipping
    if length < 1:
        print(f"Audio file '{file_name}' is too short. Padding applied.")
        log_mel_spectrogram = np.pad(log_mel_spectrogram, ((0, 0), (0, frames - 1)), mode='constant')
        length = 1
    
    for t in range(frames):
        features[:, n_mels * t: n_mels * (t + 1)] = log_mel_spectrogram[:, t: t + length].T
    
    if plot:
        plot_signals(tmin, tmax, sr, y, emphasized_y, log_mel_spectrogram)
    return features

# %%
# wav_test_file = 'dev_data_pump_04/pump/train/normal_id_04_00000000.wav'
wav_test_file = 'dev_data_pump_04/pump/test/anomaly_id_04_00000000.wav'

# Visualize your results for potential analysis in your report
features = file_to_features(wav_test_file)

# %% [markdown]
# ## PyTorch Dataset Splitting
#
# To define and optimize a neural network, we will use the library [PyTorch](http://pytorch.org).

# %%
DATA_PATH = "."
MACHINE = "pump_04" # Choice between  "valve_00" or "pump_04"

# %%
class MIMII(Dataset):
    def __init__(self, root, machine, train=True, transform=None, target_transform=None):
        if train:
            self.audio_path = os.path.join(root, f"dev_data_{machine}", machine.split("_")[0], "train")
            self.audio_files = os.listdir(self.audio_path)
            self.labels = [int(f.split("_")[0] == "anomaly") for f in self.audio_files]
        else:
            self.audio_path = os.path.join(root, f"dev_data_{machine}", machine.split("_")[0], "test")
            self.audio_files = os.listdir(self.audio_path)
            self.labels = [int(f.split("_")[0] == "anomaly") for f in self.audio_files]
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.audio_path, self.audio_files[idx])
        label = self.labels[idx]
        if self.transform:
            f = self.transform(file_path)
        else:
            # default feature representation
            f = file_to_features(file_path).astype(np.float32)
        if self.target_transform:
            label = self.target_transform(label)
        return f, label

# %%
# Parameters of the feature extraction
melsp_params = dict(n_mels=64,
                    frames=1,
                    n_fft=1024,
                    hop_length=512,
                    power=2.0,
                    plot=False)


feature_extraction_pipeline = T.Compose([
    T.Lambda(lambda file: file_to_features(file, **melsp_params).astype(np.float32)),
    T.ToTensor()
])

# %%
# Pytorch train/test datasets
data_train = MIMII(
    root=DATA_PATH,
    machine=MACHINE,
    train=True,
    transform=feature_extraction_pipeline
)

data_test = MIMII(
    root=DATA_PATH,
    machine=MACHINE,
    train=False,
    transform=feature_extraction_pipeline
)

# %% [markdown]
# ## AutoEncoder Model Definition

# %%
class DenseAutoencoder(nn.Module):

    def __init__(self, input_dim):
        super(DenseAutoencoder, self).__init__()
        # Encoder: Input -> Hidden -> Bottleneck
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            )
        
        # TODO : write a symetrical neural network to the encoder to reconstuct the input
        # ===================================
        self.decoder = nn.Sequential(
            nn.Linear(32, 128),
            nn.ReLU(),
            nn.Linear(128, 512),
            nn.ReLU(),
            nn.Linear(512, input_dim),
        )
        # ===================================

    def forward(self, x):
        feature = self.encoder(x)
        reconstruction = self.decoder(feature)
        return reconstruction,feature

# %%
duration = 10  # s
sr = 16000  # Hz
input_dim = int(duration * sr / melsp_params["hop_length"] + 1) * melsp_params["n_mels"] * melsp_params["frames"]
model = DenseAutoencoder(input_dim)

# %% [markdown]
# ## 1. Training

# %%
# Training parameters
batch_size = 32
epochs = 10

# %%
# PyTorch data loaders allow to iterate batch-wise over a dataset
train_loader = DataLoader(data_train, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
# Stochastic gradient descent optimizer
optimizer = torch.optim.Adam(model.parameters())

# Mean Squared Error (MSE) loss function to be minimized
loss_fn = nn.MSELoss()

# %%
def train_loop(dataloader, model, loss_fn, optimizer, print_every=10):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    loss_running = 0
    for batch, (x, y) in enumerate(tqdm(dataloader)):
        # Compute prediction and loss
        x = x.flatten(start_dim=1)
        optimizer.zero_grad()
        x_pred, features = model(x)
        
        # TODO : write the loss function, compute the gradient, and update the model parameters
        # ===================================
        loss = loss_fn(x_pred, x)
        loss.backward()
        optimizer.step()
        # ===================================
        
        # Back Propagation
        loss_running += loss.item()
    print(f"loss: {loss_running/len(dataloader):>7f}")


def test_loop(dataset, model, loss_fn):
    size = len(dataset)
    test_losses = np.zeros(size)
    store_feature = []
    with torch.no_grad():
        for idx, (x, _) in enumerate(dataset):
            x = x.flatten()
            x_pred,features = model(x)
            store_feature.append(features.detach().cpu().numpy())
            test_losses[idx] = loss_fn(x_pred, x).item()

    return test_losses, np.array(store_feature)

# %%
# %%time
for epoch in range(epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train_loop(train_loader, model, loss_fn, optimizer, print_every=1);
# Out:
# Epoch 1
# -------------------------------
# 100%|██████████| 18/18 [00:11<00:00,  1.51it/s]
# loss: 171.388826
# Epoch 2
# -------------------------------
# 100%|██████████| 18/18 [00:11<00:00,  1.61it/s]
# loss: 18.000505
# Epoch 3
# -------------------------------
# 100%|██████████| 18/18 [00:08<00:00,  2.12it/s]
# loss: 13.081575
# Epoch 4
# -------------------------------
# 100%|██████████| 18/18 [00:13<00:00,  1.36it/s]
# loss: 12.400795
# Epoch 5
# -------------------------------
# 100%|██████████| 18/18 [00:10<00:00,  1.66it/s]
# loss: 12.285734
# Epoch 6
# -------------------------------
# 100%|██████████| 18/18 [00:09<00:00,  1.88it/s]
# loss: 12.325295
# Epoch 7
# -------------------------------
# 100%|██████████| 18/18 [00:11<00:00,  1.55it/s]
# loss: 12.372503
# Epoch 8
# -------------------------------
# 100%|██████████| 18/18 [00:08<00:00,  2.24it/s]
# loss: 12.284943
# Epoch 9
# -------------------------------
# 100%|██████████| 18/18 [00:09<00:00,  1.80it/s]
# loss: 12.316968
# Epoch 10
# -------------------------------
# 100%|██████████| 18/18 [00:11<00:00,  1.55it/s]
# loss: 12.317676
# CPU times: user 10min 53s, sys: 30.3 s, total: 11min 23s
# Wall time: 1min 46s

# %% [markdown]
# ## Prediction and Evaluation

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score

y_true = data_test.labels
test_losses, extracted_features_test = test_loop(data_test, model, loss_fn)
y_scores = test_losses

metrics.roc_auc_score(y_true, y_scores)

# TODO : Define a threshold based on test loss for classification
# TODO : Report accuracy, TPR, FPR, F1-Score
# ===================================
# metrics.accuracy_score(y_true, y_scores)
# ===================================
# Out:
# np.float64(0.8118000000000001)

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(y_true, y_scores, name="Autoencoder")
plt.plot([0, 1], [0, 1], 'k--', linewidth=1)
plt.title(f"Receiver operating characteristic (ROC) curve for {MACHINE}");

# %% [markdown]
# ## 2. One-Class SVM and Isolation Forest
#
# From the trained AutoEncoder, use the bottleneck features to train a (1) One-Class SVM and (2) Isolation Forest, and report the accuracy, F1-score and auc score of each method.

# %%
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score

# %%
# Get normal training features
y_pred_train, extracted_features_train = test_loop(data_train, model, loss_fn)

# %% [markdown]
# ### One-Class SVM

# %%
# TODO : Define the OneClassSVM here
# TODO : Fit OneClassSVM here using training data
# TODO : Report essential evaluation metrics
# ===================================
clf = OneClassSVM()
clf.fit(extracted_features_train)
predicted_score = clf.predict(extracted_features_test) # PREDICTING ON TEST SET
predicted_score = (predicted_score == -1).astype(int)
# ===================================
roc_auc = metrics.roc_auc_score(y_true, predicted_score)
print(f"ROC AUC Score on Test Set: {roc_auc:.4f}")

accuracy = metrics.accuracy_score(y_true, predicted_score)
print(f"Accuracy Score on Test Set: {accuracy:.4f}")

f1 = metrics.f1_score(y_true, predicted_score)
print(f"F1 Score on Test Set: {f1:.4f}")
# Out:
# ROC AUC Score on Test Set: 0.4900
# Accuracy Score on Test Set: 0.4900
# F1 Score on Test Set: 0.4742

# %% [markdown]
# ### Isolation Forest

# %%
# TODO : Define IsolationForest here
# TODO : Fit IsolationForest here using training data
# TODO : Report essential evaluation metrics
# ===================================
isolation_forest = IsolationForest()
isolation_forest.fit(extracted_features_train)
predicted_score = isolation_forest.predict(extracted_features_test) # PREDICTING ON TEST SET
predicted_score = (predicted_score == -1).astype(int)
# ===================================

roc_auc = metrics.roc_auc_score(y_true, predicted_score)
print(f"ROC AUC Score on Test Set: {roc_auc:.4f}")

accuracy = metrics.accuracy_score(y_true, predicted_score)
print(f"Accuracy Score on Test Set: {accuracy:.4f}")

f1 = metrics.f1_score(y_true, predicted_score)
print(f"F1 Score on Test Set: {f1:.4f}")
# Out:
# ROC AUC Score on Test Set: 0.5650
# Accuracy Score on Test Set: 0.5650
# F1 Score on Test Set: 0.3741

# %% [markdown]
# ## 3. PCA

# %% [markdown]
# PCA of the spectrograms to reduce the input dimension

# %%
# Extract spectrograms of training and testing
flatten_spectogram_train = []
for idx, (x, _) in enumerate(data_train):
    x = x.flatten()
    flatten_spectogram_train.append(x.numpy())
train_spec = np.array(flatten_spectogram_train)

flatten_spectogram_test = []
for idx, (x, _) in enumerate(data_test):
    x = x.flatten()
    flatten_spectogram_test.append(x.numpy())
test_spec = np.array(flatten_spectogram_test)

# %% [markdown]
# Apply PCA to fit and transform the training data and transform also the test data

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=64)

# TODO : Fit and transform the training data (train_spec)
# TODO : Transform the testing data (test_spec)
# ===================================
train_spec_pca = pca.fit_transform(train_spec)
test_spec_pca = pca.transform(test_spec)
# ===================================

# %% [markdown]
# Apply OneClassSVM and IsolationForest on the new PCA features.

# %%
# TODO : Define the OneClassSVM here
# TODO : Fit OneClassSVM here using PCA features
# TODO : Report essential evaluation metrics
# ===================================
clf = OneClassSVM()
clf.fit(train_spec_pca)
predicted_score = clf.predict(test_spec_pca) # PREDICTING ON TEST SET
predicted_score = (predicted_score == -1).astype(int)

roc_auc = metrics.roc_auc_score(y_true, predicted_score)
print(f"ROC AUC Score on Test Set: {roc_auc:.4f}")

accuracy = metrics.accuracy_score(y_true, predicted_score)
print(f"Accuracy Score on Test Set: {accuracy:.4f}")

f1 = metrics.f1_score(y_true, predicted_score)
print(f"F1 Score on Test Set: {f1:.4f}")
# ===================================
# Out:
# ROC AUC Score on Test Set: 0.7900
# Accuracy Score on Test Set: 0.7900
# F1 Score on Test Set: 0.8158

# %%
# TODO : Define IsolationForest here
# TODO : Fit IsolationForest here using PCA features
# TODO : Report essential evaluation metrics
# ===================================
isolation_forest = IsolationForest()
isolation_forest.fit(train_spec_pca)
predicted_score = isolation_forest.predict(test_spec_pca) # PREDICTING ON TEST SET
predicted_score = (predicted_score == -1).astype(int)

roc_auc = metrics.roc_auc_score(y_true, predicted_score)
print(f"ROC AUC Score on Test Set: {roc_auc:.4f}")

accuracy = metrics.accuracy_score(y_true, predicted_score)
print(f"Accuracy Score on Test Set: {accuracy:.4f}")

f1 = metrics.f1_score(y_true, predicted_score)
print(f"F1 Score on Test Set: {f1:.4f}")
# ===================================
# Out:
# ROC AUC Score on Test Set: 0.5200
# Accuracy Score on Test Set: 0.5200
# F1 Score on Test Set: 0.0769

# %% [markdown]
# **Question 4:** Determine an appropriate threshold for distinguishing anomalies based on the given results, and compute the following metrics: Accuracy, True Positive Rate (TPR), False Positive Rate (FPR), and F1-score.
